# %% [markdown]
# # Food Ordering App

# %%
class Restaurant:
    def __init__(self):
        self.food = {}
        self.food_id = len(self.food) + 1 
        self.ordered_item = []
        self.personal_details = {}
        
    def common_func(self):
        print("\nSelect one option from the following :")
        print("1.Add new food items \n2.Edit food items \n3.View food items \n4.Remove a food item \n5.Exit\n")
        m=input()
        if m=="1":
            self.food_items()
        elif m=="2":
            self.edit_food_items()
        elif m=="3":
            self.all_food_items()
        elif m=="4":
            self.remove_items()
        elif m=="5":
            exit()
        else:
            print("Please choose correct option")
            self.common_func()
        
#Admin Functionalities-
    def food_items(self):
        self.name = input("Enter the food name")                  
        self.quantity = int(input("Enter the Quantity : Kg"))      
        self.price = float(input("Enter the Price"))
        self.discount = float(input("Enter the Discount"))
        self.stock = int(input("Enter the Stock"))
        self.item = {"name":self.name , "quantity":self.quantity , "price":self.price , "discount":self.discount , "stock":self.stock}
        self.food_id = len(self.food) + 1
        self.food[self.food_id] = self.item                         #Nested Dictionary
        print("Item added Successfully \n",self.food)
        
    def remove_items(self):
        delete_item = int(input("enter the Food Id you want to Delete"))
        if delete_item in self.food.keys():
            del self.food[int()]
            print("Item is Deleted")
            print("Remaining Items are",self.food)
        else:
            print("Please Enter correct food ID")
            
    def edit_food_items(self):
        f_id = int(input("Enter the Food Id you want to update :"))
        for f_id in self.food.keys():
            x= input("enter name for food name and numbers 1 for rest of values ")
            if f_id==1:
                self.food[f_id]["Name"]=input("name")
                print(" Successfully Updated ")
            elif f_id==2:
                self.food[f_id]["Quantity"]=float(input( ))
                print("\n!! Successfully Updated !!\n")
            elif f_id==3:
                self.food[f_id]["Price"]=float(input( ))
                print("\n!! Successfully Updated !!\n")
            elif f_id ==4:
                self.food[f_id]["Discount"]=float(input( ))
                print("\n!! successfully Updated !!\n")
            elif f_id==5:
                self.food[f_id]["Stock"]=float(input())    
        print("Food Item is Updated successfully",self.food)
        
                                    
    def all_food_items(self):
        print("The List of all food items are :")
        for i in self.food:
            print("Food Id:",i, "\n")
            for j in self.foods[i]:
                print(j,":",self.food[i][j])
                
                
#User Functionalities-
    def register(self):
        user_name = input("Write your Full Name")
        user_Phn_No = int(input("Please write your Phone Number"))
        user_mail_id = input("Mention your mail Id")
        user_address = input("Enter your Address")
        password = input("Select your Password")
        print("Congratulations your account is created successfully")
        
    def login(self):
        while true:
            user_id  = input("Enter your userid")
            password = input("Enter your password")
            if user_id == self.username:
                if password == self.password:
                    print("Congratulation you have successfully login")
                    break
                else:
                    print("Incorrect Details")
            else:
                print("Incorrect Details")
                  
    def place_food_item(self):
        list_of_fooditems = {}
        print("Menu list")
        user_input= int(input("Place your order:"))
        if user_input==1:
            print("Please Enter the Food Order, use comma if you want to enter more than one order")
            x = input().split(",")
            for i in x:
                y = int(i)
                if y<= len(user_input):
                    self.ordered_item.append(menu[y-1])
                else:
                    print("Pardon Order no found  \n Try again")
            for j in self.ordered_item:
                print(j)
       
    
        
    def order_history(self):
        for i in ordered_item:
            print(i)
            
            
    def update_profile(self):
        print("What do you want to update?\n 1.Name \n 2.Phone no \n 3.Mail Id \n 4.Address \n 5.Password")
        update_no= int(input())
        if  update_no=="1":
            self.personal_details["Name"] = input("Write your Full Name")
            print("Name Updated Successfuly")
        elif update_no=="2":
            self.personal_details["Phn_no"] = input("Write your Phone Number")
            print("Phone Number Updated Successfuly")
        elif update_no=="3":
            self.personal_details["Mail_ID"] = input("Write your Mail Id")
            print("Mail Id Updated Successfuly")
        elif update_no=="4":
            self.personal_details["Address"] = input("Write your Address")
            print("Address Updated Successfuly")
        elif update_no=="5":
            self.personal_details["Password"]= input("Write your Password")
            print("Password Updated Successfuly")
        print("Congratulations profile updated successfully")
        
def data(food_data,prev_orders):
    
        person=input()
        user=[]
        if person=="1":
        
            admin_email=input("Enter admin email: ")
            admin_pass= input("Enter admin password: ")
            print()
            if admin_email=="animesh177@gmail.com" and ad_pass=="Helloanii":
                admin_login=admin(admin_email,admin_pass,food_data)
                admin_login.common_func()   
            else:
                print("Please enter correct email and password")
                calling_func()
    
        elif person=="2": #new user
            full_name=input("Enter your full name: ")
            phone=input("Enter your phone number: ")
            email=input("Enter your email address: ")
            address=input("Enter your address: ")
            password=input("Enter your password: ")
            create_user=user(email,password,full_name,phone,address,food_data,prev_orders)
            print("succesfully login")
        elif person=="3":
            exit()

        else:
            print("Please choose correct option")
            calling_func()
            
            
            
        
def calling_func():
    print("\nChoose any one option from the following :")
    print("1.Admin login \n2.User Login \n3.Exit\n")
    data([["Tandoori Chicken","4 pieces","INR 240","10% OFF",2],["Vegan Burger","1 piece","INR 320","10% OFF",2],["Truffle Cake","500 gm","INR 900","10% OFF",2]],[])


print("Welcome")
calling_func()
# Out:
# Welcome
#
# Choose any one option from the following :
# 1.Admin login
# 2.User Login
# 3.Exit
